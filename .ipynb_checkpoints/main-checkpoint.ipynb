# %% [markdown]
# PRELIMINARY STEP: import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# import warnings in order to get rid of them

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Reading the dataset thanks to the built-in function in pandas.

# %%
ds = pd.read_csv("./credit_prediction.csv")  #open and read the file using pandas

# %%
ds.head(10) #show the first 10 elements
# Out:
#    id   Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0   0  23.0  Scientist       19114.12            1824.843333
# 1   1  23.0  Scientist            NaN            1824.843333
# 2   2  23.0  Scientist       19114.12            1824.843333
# 3   3  23.0  Scientist       19114.12            1824.843333
# 4   4  23.0        NaN       19114.12            1824.843333
# 5   5  23.0  Scientist       19114.12            1824.843333
# 6   6  23.0  Scientist       19114.12            1824.843333
# 7   7  23.0  Scientist       19114.12            1824.843333
# 8   8  28.0    Teacher       34847.84            3037.986667
# 9   9  28.0    Teacher       34847.84            3037.986667
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                3.0              4.0            3.0          4.0
# 1                3.0              4.0            3.0          4.0
# 2                3.0              4.0            3.0          NaN
# 3                NaN              4.0            3.0          4.0
# 4                3.0              4.0            3.0          4.0
# 5                3.0              4.0            3.0          4.0
# 6                3.0              4.0            3.0          4.0
# 7                3.0              4.0            3.0          4.0
# 8                2.0              4.0            6.0          NaN
# 9                NaN              4.0            6.0          1.0
#
#                                         Type_of_Loan  ...  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# 2  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# 3  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# 4  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# 5  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# 6  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# 7  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# 8                                Credit-Builder Loan  ...
# 9                                Credit-Builder Loan  ...
#
#    Num_Credit_Inquiries  Credit_Mix  Outstanding_Debt  \
# 0                   4.0        Good            809.98
# 1                   4.0        Good            809.98
# 2                   4.0        Good            809.98
# 3                   NaN        Good            809.98
# 4                   4.0        Good            809.98
# 5                   4.0        Good            809.98
# 6                   4.0        Good            809.98
# 7                   4.0        Good            809.98
# 8                   2.0        Good            605.03
# 9                   2.0        Good            605.03
#
#    Credit_Utilization_Ratio Credit_History_Age  Payment_of_Min_Amount  \
# 0                 26.822620              265.0                     No
# 1                       NaN              266.0                     No
# 2                 28.609352              267.0                     No
# 3                 31.377862              268.0                     No
# 4                 24.797347              269.0                     No
# 5                 27.262259              270.0                     No
# 6                       NaN              271.0                     No
# 7                 23.933795                NaN                     No
# 8                       NaN              319.0                    NaN
# 9                 38.550848              320.0                     No
#
#    Amount_invested_monthly                 Payment_Behaviour Monthly_Balance  \
# 0                80.415295                               NaN      312.494089
# 1               118.280222    Low_spent_Large_value_payments      284.629162
# 2                81.699521   Low_spent_Medium_value_payments      331.209863
# 3               199.458074    Low_spent_Small_value_payments      223.451310
# 4                41.420153  High_spent_Medium_value_payments      341.489231
# 5                62.430172  High_spent_Medium_value_payments      340.479212
# 6               178.344067    Low_spent_Small_value_payments      244.565317
# 7                24.785217  High_spent_Medium_value_payments      358.124168
# 8                      NaN    Low_spent_Small_value_payments      470.690627
# 9                40.391238   High_spent_Large_value_payments      484.591214
#
#    Credit_Score
# 0          Good
# 1          Good
# 2          Good
# 3          Good
# 4          Good
# 5          Good
# 6          Good
# 7      Standard
# 8      Standard
# 9          Good
#
# [10 rows x 23 columns]

# %%
ds.duplicated().sum() #let's see how many duplicates
# Out:
# 0

# %%
sns.heatmap(ds.isna(), cbar = False) #to visualize null values for each column
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x = ds['Credit_Score']) #to visualize how many of them
# Out:
# <AxesSubplot:xlabel='Credit_Score', ylabel='count'>

# %%
ds.groupby(['Credit_Score']).count()
# Out:
#                  id    Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# Credit_Score
# Good          17828  16097       16013          16025                  15924
# Poor          28998  26169       26044          26056                  26145
# Standard      53174  47847       47897          47730                  47812
#
#               Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# Credit_Score
# Good                      16125            16075          16050        16052
# Poor                      26047            26103          26081        26138
# Standard                  47763            47953          47868        47840
#
#               Type_of_Loan  ...  Changed_Credit_Limit  Num_Credit_Inquiries  \
# Credit_Score                ...
# Good                 16056  ...                 16071                 16049
# Poor                 26003  ...                 26131                 26142
# Standard             47862  ...                 47875                 47780
#
#               Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# Credit_Score
# Good               15963             16078                     16053
# Poor               26199             26197                     26122
# Standard           47733             47879                     47813
#
#               Credit_History_Age  Payment_of_Min_Amount  \
# Credit_Score
# Good                       16012                  16113
# Poor                       26056                  26044
# Standard                   47948                  47885
#
#               Amount_invested_monthly  Payment_Behaviour  Monthly_Balance
# Credit_Score
# Good                            15972              16107            16102
# Poor                            26135              26062            26036
# Standard                        47848              47755            47963
#
# [3 rows x 22 columns]

# %% [markdown]
# In order to visualize the trend of some variables we should plot them, using an histogram.

# %%
ds['Annual_Income'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ds['Monthly_Inhand_Salary'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ds['Amount_invested_monthly'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# We need to transform categorical variables into numerical ones.

# %%
#we can eliminate a priori the column 'id' as it is not needed
ds = ds.drop(columns=['id'])
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Age                       90113 non-null   float64
#  1   Occupation                89954 non-null   object
#  2   Annual_Income             89811 non-null   float64
#  3   Monthly_Inhand_Salary     89881 non-null   float64
#  4   Num_Bank_Accounts         89935 non-null   float64
#  5   Num_Credit_Card           90131 non-null   float64
#  6   Interest_Rate             89999 non-null   float64
#  7   Num_of_Loan               90030 non-null   float64
#  8   Type_of_Loan              89921 non-null   object
#  9   Delay_from_due_date       90053 non-null   float64
#  10  Num_of_Delayed_Payment    89927 non-null   float64
#  11  Changed_Credit_Limit      90077 non-null   float64
#  12  Num_Credit_Inquiries      89971 non-null   float64
#  13  Credit_Mix                89895 non-null   object
#  14  Outstanding_Debt          90154 non-null   float64
#  15  Credit_Utilization_Ratio  89988 non-null   float64
#  16  Credit_History_Age        90016 non-null   float64
#  17  Payment_of_Min_Amount     90042 non-null   object
#  18  Amount_invested_monthly   89955 non-null   float64
#  19  Payment_Behaviour         89924 non-null   object
#  20  Monthly_Balance           90101 non-null   float64
#  21  Credit_Score              100000 non-null  object
# dtypes: float64(16), object(6)
# memory usage: 16.8+ MB

# %%
from sklearn.preprocessing import LabelEncoder
ds['Credit_Mix'] = LabelEncoder().fit_transform(ds['Credit_Mix'])
ds['Payment_Behaviour'] = LabelEncoder().fit_transform(ds['Payment_Behaviour'])
ds['Occupation'] = LabelEncoder().fit_transform(ds['Occupation'])
ds['Type_of_Loan'] = LabelEncoder().fit_transform(ds['Type_of_Loan'])
ds['Payment_of_Min_Amount'] = LabelEncoder().fit_transform(ds['Payment_of_Min_Amount'])

ds.head()

# %%
ds.corr() #to see correlations, but all categorical ones will be ignored, so change them
# Out:
#                                Age  Occupation  Annual_Income  \
# Age                       1.000000    0.000250       0.094214
# Occupation                0.000250    1.000000       0.000648
# Annual_Income             0.094214    0.000648       1.000000
# Monthly_Inhand_Salary     0.092432    0.001313       0.998155
# Num_Bank_Accounts        -0.192405    0.009864      -0.285732
# Num_Credit_Card          -0.147670    0.004693      -0.218083
# Interest_Rate            -0.218744    0.003234      -0.302391
# Num_of_Loan              -0.215283   -0.004587      -0.256766
# Type_of_Loan              0.010223   -0.005364       0.014369
# Delay_from_due_date      -0.175110    0.007855      -0.249761
# Num_of_Delayed_Payment   -0.186063   -0.008362      -0.287701
# Changed_Credit_Limit     -0.158929   -0.001963      -0.177471
# Num_Credit_Inquiries     -0.251603    0.001500      -0.280632
# Credit_Mix                0.060897    0.002422       0.078006
# Outstanding_Debt         -0.202975    0.004877      -0.269997
# Credit_Utilization_Ratio  0.023721   -0.002016       0.177065
# Credit_History_Age        0.235896   -0.006510       0.272721
# Payment_of_Min_Amount    -0.124852   -0.002216      -0.150307
# Amount_invested_monthly   0.006597    0.003266       0.055108
# Payment_Behaviour        -0.030798    0.004240      -0.265724
# Monthly_Balance          -0.002635    0.000573      -0.004711
#
#                           Monthly_Inhand_Salary  Num_Bank_Accounts  \
# Age                                    0.092432          -0.192405
# Occupation                             0.001313           0.009864
# Annual_Income                          0.998155          -0.285732
# Monthly_Inhand_Salary                  1.000000          -0.283303
# Num_Bank_Accounts                     -0.283303           1.000000
# Num_Credit_Card                       -0.216476           0.442678
# Interest_Rate                         -0.301315           0.583227
# Num_of_Loan                           -0.256375           0.472694
# Type_of_Loan                           0.018436          -0.012213
# Delay_from_due_date                   -0.249382           0.560583
# Num_of_Delayed_Payment                -0.285382           0.601553
# Changed_Credit_Limit                  -0.175202           0.333300
# Num_Credit_Inquiries                  -0.279105           0.515379
# Credit_Mix                             0.077388          -0.184559
# Outstanding_Debt                      -0.269707           0.506999
# Credit_Utilization_Ratio               0.178518          -0.070942
# Credit_History_Age                     0.271030          -0.485478
# Payment_of_Min_Amount                 -0.151819           0.280019
# Amount_invested_monthly                0.053704          -0.015364
# Payment_Behaviour                     -0.266155           0.080292
# Monthly_Balance                       -0.004176           0.005845
#
#                           Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# Age                             -0.147670      -0.218744    -0.215283
# Occupation                       0.004693       0.003234    -0.004587
# Annual_Income                   -0.218083      -0.302391    -0.256766
# Monthly_Inhand_Salary           -0.216476      -0.301315    -0.256375
# Num_Bank_Accounts                0.442678       0.583227     0.472694
# Num_Credit_Card                  1.000000       0.499178     0.417508
# Interest_Rate                    0.499178       1.000000     0.560036
# Num_of_Loan                      0.417508       0.560036     1.000000
# Type_of_Loan                    -0.008954      -0.013564    -0.028766
# Delay_from_due_date              0.479751       0.591529     0.503398
# Num_of_Delayed_Payment           0.424036       0.571366     0.473959
# Changed_Credit_Limit             0.253572       0.370325     0.374885
# Num_Credit_Inquiries             0.458086       0.631691     0.564533
# Credit_Mix                      -0.263867      -0.259463    -0.351639
# Outstanding_Debt                 0.491157       0.628982     0.639486
# Credit_Utilization_Ratio        -0.055238      -0.077353    -0.101013
# Credit_History_Age              -0.416870      -0.576643    -0.606878
# Payment_of_Min_Amount            0.199322       0.297324     0.248270
# Amount_invested_monthly         -0.010274      -0.018500    -0.012386
# Payment_Behaviour                0.063975       0.090950     0.077168
# Monthly_Balance                  0.004964       0.004477     0.001958
#
#                           Type_of_Loan  Delay_from_due_date  ...  \
# Age                           0.010223            -0.175110  ...
# Occupation                   -0.005364             0.007855  ...
# Annual_Income                 0.014369            -0.249761  ...
# Monthly_Inhand_Salary         0.018436            -0.249382  ...
# Num_Bank_Accounts            -0.012213             0.560583  ...
# Num_Credit_Card              -0.008954             0.479751  ...
# Interest_Rate                -0.013564             0.591529  ...
# Num_of_Loan                  -0.028766             0.503398  ...
# Type_of_Loan                  1.000000            -0.018956  ...
# Delay_from_due_date          -0.018956             1.000000  ...
# Num_of_Delayed_Payment       -0.017734             0.540332  ...
# Changed_Credit_Limit         -0.016538             0.296495  ...
# Num_Credit_Inquiries         -0.004203             0.539325  ...
# Credit_Mix                    0.005605            -0.326715  ...
# Outstanding_Debt             -0.016616             0.572768  ...
# Credit_Utilization_Ratio      0.005935            -0.064390  ...
# Credit_History_Age            0.011068            -0.489846  ...
# Payment_of_Min_Amount        -0.006912             0.243713  ...
# Amount_invested_monthly      -0.001155            -0.009811  ...
# Payment_Behaviour            -0.001686             0.077015  ...
# Monthly_Balance              -0.002888             0.004988  ...
#
#                           Changed_Credit_Limit  Num_Credit_Inquiries  \
# Age                                  -0.158929             -0.251603
# Occupation                           -0.001963              0.001500
# Annual_Income                        -0.177471             -0.280632
# Monthly_Inhand_Salary                -0.175202             -0.279105
# Num_Bank_Accounts                     0.333300              0.515379
# Num_Credit_Card                       0.253572              0.458086
# Interest_Rate                         0.370325              0.631691
# Num_of_Loan                           0.374885              0.564533
# Type_of_Loan                         -0.016538             -0.004203
# Delay_from_due_date                   0.296495              0.539325
# Num_of_Delayed_Payment                0.328173              0.499689
# Changed_Credit_Limit                  1.000000              0.383047
# Num_Credit_Inquiries                  0.383047              1.000000
# Credit_Mix                           -0.065587             -0.267859
# Outstanding_Debt                      0.463555              0.597357
# Credit_Utilization_Ratio             -0.046592             -0.079951
# Credit_History_Age                   -0.430469             -0.608461
# Payment_of_Min_Amount                 0.246309              0.302389
# Amount_invested_monthly              -0.008353             -0.017745
# Payment_Behaviour                     0.048902              0.086762
# Monthly_Balance                      -0.000489             -0.002554
#
#                           Credit_Mix  Outstanding_Debt  \
# Age                         0.060897         -0.202975
# Occupation                  0.002422          0.004877
# Annual_Income               0.078006         -0.269997
# Monthly_Inhand_Salary       0.077388         -0.269707
# Num_Bank_Accounts          -0.184559          0.506999
# Num_Credit_Card            -0.263867          0.491157
# Interest_Rate              -0.259463          0.628982
# Num_of_Loan                -0.351639          0.639486
# Type_of_Loan                0.005605         -0.016616
# Delay_from_due_date        -0.326715          0.572768
# Num_of_Delayed_Payment     -0.195698          0.503561
# Changed_Credit_Limit       -0.065587          0.463555
# Num_Credit_Inquiries       -0.267859          0.597357
# Credit_Mix                  1.000000         -0.458926
# Outstanding_Debt           -0.458926          1.000000
# Credit_Utilization_Ratio    0.025971         -0.072577
# Credit_History_Age          0.272715         -0.629102
# Payment_of_Min_Amount      -0.014331          0.234462
# Amount_invested_monthly     0.001187         -0.013246
# Payment_Behaviour          -0.029618          0.083036
# Monthly_Balance            -0.004519          0.001235
#
#                           Credit_Utilization_Ratio  Credit_History_Age  \
# Age                                       0.023721            0.235896
# Occupation                               -0.002016           -0.006510
# Annual_Income                             0.177065            0.272721
# Monthly_Inhand_Salary                     0.178518            0.271030
# Num_Bank_Accounts                        -0.070942           -0.485478
# Num_Credit_Card                          -0.055238           -0.416870
# Interest_Rate                            -0.077353           -0.576643
# Num_of_Loan                              -0.101013           -0.606878
# Type_of_Loan                              0.005935            0.011068
# Delay_from_due_date                      -0.064390           -0.489846
# Num_of_Delayed_Payment                   -0.072964           -0.481637
# Changed_Credit_Limit                     -0.046592           -0.430469
# Num_Credit_Inquiries                     -0.079951           -0.608461
# Credit_Mix                                0.025971            0.272715
# Outstanding_Debt                         -0.072577           -0.629102
# Credit_Utilization_Ratio                  1.000000            0.073614
# Credit_History_Age                        0.073614            1.000000
# Payment_of_Min_Amount                    -0.040411           -0.284175
# Amount_invested_monthly                   0.001987            0.016873
# Payment_Behaviour                        -0.106230           -0.082285
# Monthly_Balance                          -0.004748           -0.003798
#
#                           Payment_of_Min_Amount  Amount_invested_monthly  \
# Age                                   -0.124852                 0.006597
# Occupation                            -0.002216                 0.003266
# Annual_Income                         -0.150307                 0.055108
# Monthly_Inhand_Salary                 -0.151819                 0.053704
# Num_Bank_Accounts                      0.280019                -0.015364
# Num_Credit_Card                        0.199322                -0.010274
# Interest_Rate                          0.297324                -0.018500
# Num_of_Loan                            0.248270                -0.012386
# Type_of_Loan                          -0.006912                -0.001155
# Delay_from_due_date                    0.243713                -0.009811
# Num_of_Delayed_Payment                 0.287989                -0.021178
# Changed_Credit_Limit                   0.246309                -0.008353
# Num_Credit_Inquiries                   0.302389                -0.017745
# Credit_Mix                            -0.014331                 0.001187
# Outstanding_Debt                       0.234462                -0.013246
# Credit_Utilization_Ratio              -0.040411                 0.001987
# Credit_History_Age                    -0.284175                 0.016873
# Payment_of_Min_Amount                  1.000000                -0.011148
# Amount_invested_monthly               -0.011148                 1.000000
# Payment_Behaviour                      0.042732                 0.018440
# Monthly_Balance                        0.005965                 0.002295
#
#                           Payment_Behaviour  Monthly_Balance
# Age                               -0.030798        -0.002635
# Occupation                         0.004240         0.000573
# Annual_Income                     -0.265724        -0.004711
# Monthly_Inhand_Salary             -0.266155        -0.004176
# Num_Bank_Accounts                  0.080292         0.005845
# Num_Credit_Card                    0.063975         0.004964
# Interest_Rate                      0.090950         0.004477
# Num_of_Loan                        0.077168         0.001958
# Type_of_Loan                      -0.001686        -0.002888
# Delay_from_due_date                0.077015         0.004988
# Num_of_Delayed_Payment             0.084444         0.007799
# Changed_Credit_Limit               0.048902        -0.000489
# Num_Credit_Inquiries               0.086762        -0.002554
# Credit_Mix                        -0.029618        -0.004519
# Outstanding_Debt                   0.083036         0.001235
# Credit_Utilization_Ratio          -0.106230        -0.004748
# Credit_History_Age                -0.082285        -0.003798
# Payment_of_Min_Amount              0.042732         0.005965
# Amount_invested_monthly            0.018440         0.002295
# Payment_Behaviour                  1.000000        -0.003225
# Monthly_Balance                   -0.003225         1.000000
#
# [21 rows x 21 columns]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Age                       90113 non-null   float64
#  1   Occupation                100000 non-null  int32
#  2   Annual_Income             89811 non-null   float64
#  3   Monthly_Inhand_Salary     89881 non-null   float64
#  4   Num_Bank_Accounts         89935 non-null   float64
#  5   Num_Credit_Card           90131 non-null   float64
#  6   Interest_Rate             89999 non-null   float64
#  7   Num_of_Loan               90030 non-null   float64
#  8   Type_of_Loan              100000 non-null  int32
#  9   Delay_from_due_date       90053 non-null   float64
#  10  Num_of_Delayed_Payment    89927 non-null   float64
#  11  Changed_Credit_Limit      90077 non-null   float64
#  12  Num_Credit_Inquiries      89971 non-null   float64
#  13  Credit_Mix                100000 non-null  int32
#  14  Outstanding_Debt          90154 non-null   float64
#  15  Credit_Utilization_Ratio  89988 non-null   float64
#  16  Credit_History_Age        90016 non-null   float64
#  17  Payment_of_Min_Amount     100000 non-null  int32
#  18  Amount_invested_monthly   89955 non-null   float64
#  19  Payment_Behaviour         100000 non-null  int32
#  20  Monthly_Balance           90101 non-null   float64
#  21  Credit_Score              100000 non-null  object
# dtypes: float64(16), int32(5), object(1)
# memory usage: 14.9+ MB

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

pipeline=ColumnTransformer([('num',StandardScaler(),[0,2,3,4,5,6,7,9,10,11,12,14,15,16,18,20]),('cat',OneHotEncoder(handle_unknown='ignore'),[1,8,13,17,19])])
# Out:
#     Age  Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  23.0          12       19114.12            1824.843333                3.0
# 1  23.0          12            NaN            1824.843333                3.0
# 2  23.0          12       19114.12            1824.843333                3.0
# 3  23.0          12       19114.12            1824.843333                NaN
# 4  23.0          15       19114.12            1824.843333                3.0
#
#    Num_Credit_Card  Interest_Rate  Num_of_Loan  Type_of_Loan  \
# 0              4.0            3.0          4.0           128
# 1              4.0            3.0          4.0           128
# 2              4.0            3.0          NaN           128
# 3              4.0            3.0          4.0           128
# 4              4.0            3.0          4.0           128
#
#    Delay_from_due_date  ...  Num_Credit_Inquiries  Credit_Mix  \
# 0                  3.0  ...                   4.0           1
# 1                 -1.0  ...                   4.0           1
# 2                  3.0  ...                   4.0           1
# 3                  5.0  ...                   NaN           1
# 4                  NaN  ...                   4.0           1
#
#    Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 0            809.98                 26.822620               265.0
# 1            809.98                       NaN               266.0
# 2            809.98                 28.609352               267.0
# 3            809.98                 31.377862               268.0
# 4            809.98                 24.797347               269.0
#
#    Payment_of_Min_Amount  Amount_invested_monthly  Payment_Behaviour  \
# 0                      1                80.415295                  6
# 1                      1               118.280222                  3
# 2                      1                81.699521                  4
# 3                      1               199.458074                  5
# 4                      1                41.420153                  1
#
#    Monthly_Balance  Credit_Score
# 0       312.494089          Good
# 1       284.629162          Good
# 2       331.209863          Good
# 3       223.451310          Good
# 4       341.489231          Good
#
# [5 rows x 22 columns]

# %%
ds.describe() #statistical summary
# Out:
#                 Age     Occupation  Annual_Income  Monthly_Inhand_Salary  \
# count  90113.000000  100000.000000   89811.000000           89881.000000
# mean      33.333914       7.756050   50508.427543            4195.570378
# std       10.765661       4.751941   38260.589378            3187.983172
# min       14.000000       0.000000    7005.930000             303.645417
# 25%       24.000000       4.000000   19375.760000            1625.265833
# 50%       33.000000       8.000000   37062.360000            3089.424167
# 75%       42.000000      12.000000   71690.050000            5955.740000
# max       56.000000      15.000000  179987.280000           15204.633333
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate   Num_of_Loan  \
# count       89935.000000     90131.000000   89999.000000  90030.000000
# mean            5.362662         5.533756      14.523750      3.535210
# std             2.591123         2.068676       8.740063      2.449893
# min            -1.000000         0.000000       1.000000      0.000000
# 25%             3.000000         4.000000       7.000000      2.000000
# 50%             5.000000         5.000000      13.000000      3.000000
# 75%             7.000000         7.000000      20.000000      5.000000
# max            11.000000        11.000000      34.000000      9.000000
#
#         Type_of_Loan  Delay_from_due_date  ...  Changed_Credit_Limit  \
# count  100000.000000         90053.000000  ...          90077.000000
# mean     3504.795890            21.073290  ...             10.472639
# std      1869.521851            14.811333  ...              6.604692
# min         0.000000            -1.000000  ...              0.500000
# 25%      2082.000000            10.000000  ...              5.380000
# 50%      3463.000000            18.000000  ...              9.410000
# 75%      5088.000000            28.000000  ...             14.850000
# max      6261.000000            62.000000  ...             29.980000
#
#        Num_Credit_Inquiries     Credit_Mix  Outstanding_Debt  \
# count          89971.000000  100000.000000      90154.000000
# mean               5.805604       1.399340       1425.180996
# std                3.871103       0.933786       1153.400024
# min                0.000000       0.000000          0.230000
# 25%                3.000000       1.000000        566.210000
# 50%                5.000000       2.000000       1165.770000
# 75%                8.000000       2.000000       1945.030000
# max               17.000000       3.000000       4998.070000
#
#        Credit_Utilization_Ratio  Credit_History_Age  Payment_of_Min_Amount  \
# count              89988.000000        90016.000000          100000.000000
# mean                  32.286539          221.104315               1.561070
# std                    5.112481           99.670715               0.814345
# min                   20.100770            1.000000               0.000000
# 25%                   28.056378          144.000000               1.000000
# 50%                   32.306529          219.000000               2.000000
# 75%                   36.498857          302.000000               2.000000
# max                   50.000000          404.000000               3.000000
#
#        Amount_invested_monthly  Payment_Behaviour  Monthly_Balance
# count             89955.000000      100000.000000     9.010100e+04
# mean                647.642318           3.085590    -3.699552e+22
# std                2078.487082           2.011831     3.511497e+24
# min                   0.000000           0.000000    -3.333333e+26
# 25%                  70.500462           1.000000     2.675203e+02
# 50%                 130.603247           3.000000     3.338268e+02
# 75%                 258.734805           5.000000     4.635211e+02
# max               10000.000000           6.000000     1.183931e+03
#
# [8 rows x 21 columns]

# %% [markdown]
# In order to see the popularity of age

# %%
plt.figure(figsize=(10,6))
sns.histplot(ds['Age'], bins=[0,15,30,45,60,75])
plt.xticks(rotation=90);

# %%
#replace missing values with the mode if they are categorical variables and th mean for the numerical ones

for i in ds.columns[:-1]:
    
    if i == 'Credit_Mix' or i == 'Payment_Behaviour' or i == 'Occupation' or i == 'Type_of_Loan' or i == 'Payment_of_Min_Amount':
        ds[i].fillna(ds[i].mode()[0], inplace = True)
    else:
        ds[i].fillna(ds[i].mean(), inplace = True)
        
ds.isnull().sum() #check how many null values in ds now
# Out:
# Age                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
ds.info() #contains the number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column (non-null values).
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Age                       100000 non-null  float64
#  1   Occupation                100000 non-null  int32
#  2   Annual_Income             100000 non-null  float64
#  3   Monthly_Inhand_Salary     100000 non-null  float64
#  4   Num_Bank_Accounts         100000 non-null  float64
#  5   Num_Credit_Card           100000 non-null  float64
#  6   Interest_Rate             100000 non-null  float64
#  7   Num_of_Loan               100000 non-null  float64
#  8   Type_of_Loan              100000 non-null  int32
#  9   Delay_from_due_date       100000 non-null  float64
#  10  Num_of_Delayed_Payment    100000 non-null  float64
#  11  Changed_Credit_Limit      100000 non-null  float64
#  12  Num_Credit_Inquiries      100000 non-null  float64
#  13  Credit_Mix                100000 non-null  int32
#  14  Outstanding_Debt          100000 non-null  float64
#  15  Credit_Utilization_Ratio  100000 non-null  float64
#  16  Credit_History_Age        100000 non-null  float64
#  17  Payment_of_Min_Amount     100000 non-null  int32
#  18  Amount_invested_monthly   100000 non-null  float64
#  19  Payment_Behaviour         100000 non-null  int32
#  20  Monthly_Balance           100000 non-null  float64
#  21  Credit_Score              100000 non-null  object
# dtypes: float64(16), int32(5), object(1)
# memory usage: 14.9+ MB

# %% [markdown]
# ### Remove outliers

# %% [markdown]
# Outliers are points that are noticebly different from the others, this is why it is better to remove them.
# We have decided to visualize them thanks to the boxplot, realized thanks to seaborn.

# %%
from numpy import percentile

# %%
fig, axs = plt.subplots(7,3)
fig.set_figwidth(15)
fig.set_figheight(25)

a = 0
b = 0 
for x in ds.columns:
    axs[b][a].set_title(x)
    axs[b, a].boxplot(ds[x], patch_artist=True)
    if a == 2:
        a = 0
        b = b+1
    else:
        a = a+1
    if b == 7:
        break

# %%
fig, axs = plt.subplots(7,3)
fig.set_figwidth(15)
fig.set_figheight(25)

a = 0
b = 0 
for x in ds.columns:
    #a = sns.boxplot(ds[x])
    q25, q75 = percentile(ds[x], 25), percentile(ds[x], 75)
    iqr = q75 - q25
    print('Percentiles: 25th=%.3f, 75th=%.3f, IQR=%.3f' % (q25, q75, iqr))


    cut_off = iqr * 1.5
    lower, upper = q25 - cut_off, q75 + cut_off

    outliers = [j for j in ds[x] if j < lower or j > upper]
    print('\nThe number of identified outliers for the variable', x ,'is:\n' '%d' % len(outliers))

    if len(outliers) != 0:
        for i in outliers:
            ds[x] = ds[x].replace(i,ds[x].mean())
# using the variable axs for multiple Axes
    axs[b][a].set_title(x)
    axs[b, a].boxplot(ds[x], patch_artist=True)
    if a == 2:
        a = 0
        b = b+1
    else:
        a = a+1
    if b == 7:
        break
# Out:
# Percentiles: 25th=25.000, 75th=41.000, IQR=16.000
#
# The number of identified outliers for the variable Age is:
# 0
# Percentiles: 25th=4.000, 75th=12.000, IQR=8.000
#
# The number of identified outliers for the variable Occupation is:
# 0
# Percentiles: 25th=20347.965, 75th=67531.720, IQR=47183.755
#
# The number of identified outliers for the variable Annual_Income is:
# 3138
# Percentiles: 25th=1724.938, 75th=5582.571, IQR=3857.632
#
# The number of identified outliers for the variable Monthly_Inhand_Salary is:
# 3371
# Percentiles: 25th=4.000, 75th=7.000, IQR=3.000
#
# The number of identified outliers for the variable Num_Bank_Accounts is:
# 19
# Percentiles: 25th=4.000, 75th=7.000, IQR=3.000
#
# The number of identified outliers for the variable Num_Credit_Card is:
# 0
# Percentiles: 25th=8.000, 75th=19.000, IQR=11.000
#
# The number of identified outliers for the variable Interest_Rate is:
# 0
# Percentiles: 25th=2.000, 75th=5.000, IQR=3.000
#
# The number of identified outliers for the variable Num_of_Loan is:
# 0
# Percentiles: 25th=2082.000, 75th=5088.000, IQR=3006.000
#
# The number of identified outliers for the variable Type_of_Loan is:
# 0
# Percentiles: 25th=11.000, 75th=27.000, IQR=16.000
#
# The number of identified outliers for the variable Delay_from_due_date is:
# 5755
# Percentiles: 25th=9.000, 75th=18.000, IQR=9.000
#
# The number of identified outliers for the variable Num_of_Delayed_Payment is:
# 0
# Percentiles: 25th=5.930, 75th=13.870, IQR=7.940
#
# The number of identified outliers for the variable Changed_Credit_Limit is:
# 2782
# Percentiles: 25th=3.000, 75th=8.000, IQR=5.000
#
# The number of identified outliers for the variable Num_Credit_Inquiries is:
# 729
# Percentiles: 25th=1.000, 75th=2.000, IQR=1.000
#
# The number of identified outliers for the variable Credit_Mix is:
# 0
# Percentiles: 25th=632.460, 75th=1760.010, IQR=1127.550
#
# The number of identified outliers for the variable Outstanding_Debt is:
# 7696
# Percentiles: 25th=28.537, 75th=36.033, IQR=7.496
#
# The number of identified outliers for the variable Credit_Utilization_Ratio is:
# 19
# Percentiles: 25th=155.000, 75th=291.000, IQR=136.000
#
# The number of identified outliers for the variable Credit_History_Age is:
# 0
# Percentiles: 25th=1.000, 75th=2.000, IQR=1.000
#
# The number of identified outliers for the variable Payment_of_Min_Amount is:
# 0
# Percentiles: 25th=76.154, 75th=372.058, IQR=295.904
#
# The number of identified outliers for the variable Amount_invested_monthly is:
# 5984
# Percentiles: 25th=1.000, 75th=5.000, IQR=4.000
#
# The number of identified outliers for the variable Payment_Behaviour is:
# 0
# Percentiles: 25th=244.281, 75th=442.440, IQR=198.159
#
# The number of identified outliers for the variable Monthly_Balance is:
# 17156

# %% [markdown]
# After having looked at our dataset and having cleaned it, we can now start collecting data into array of dependent (what we want to predict) and independent variables

# %%
#collect data into arrays
X = ds.iloc[:, :-1].values      #independent variable
y = ds.iloc[:, -1].values       #dependent variable

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
#encode data. This step is really important, we have already transformed the categorical data into integers. REMEMBER, NEVER TRAIN ON THE TEST SET!!
print(type(X_train))
X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)
X_train.shape
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>
# <class 'scipy.sparse._csr.csr_matrix'>

# %% [markdown]
# We can now decide three models that can help us solving this problem.

# %%
from sklearn.svm import SVC 
from sklearn import neighbors
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, recall_score

# %% [markdown]
# Kernel SVC classifier

# %%
param_grid = {'kernel':('linear', 'rbf', 'poly', 'sigmoid'), 'C':[0.1,1, 10], 'max_iter':[2000]}
svc = SVC()
clf_svc = GridSearchCV(svc, param_grid, cv=10, scoring='accuracy', return_train_score=False, verbose=1)

clf_svc.fit(X_train,y_train)
print(clf_svc.best_params_)

y_pred_svc = svc.predict(X_test)
print(classification_report(y_test, y_pred_svc))

_ = ConfusionMatrixDisplay.from_predictions(y_test, y_pred_svc)

# %% [markdown]
# In order to reduce the size we apply the PCA (Principal Component Analysis).

# %% [markdown]
# XGBOOST Classifier

# %%
#size = 10
param_grid = {'max_depth':[8, 11, 15],
              #'lambda': np.random.uniform(1e-3,10,size).tolist(),
              #'alpha': np.random.uniform(1e-3,10,size).tolist(),
              #'colsample_bytree': np.random.uniform(0.3,1,size).tolist(),
              'learning_rate':[0.1, 0.001], #loguniform distribution
              #'min_child_weight':np.random.randint(1,300,size).tolist()
              }
xgb = XGBClassifier()
clf_xgb = GridSearchCV(xgb, param_grid, cv=10, scoring='accuracy', return_train_score=False, verbose=1)


clf_xgb.fit(X_train,y_train)

print(clf_xgb.best_params_)
y_pred_xgb = clf_xgb.predict(X_test)
print(classification_report(y_test, y_pred_xgb))


_ = ConfusionMatrixDisplay.from_predictions(y_test, y_pred_xgb)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [18:14:34] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:16:03] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [102], line 13
#       9 xgb = XGBClassifier()
#      10 clf_xgb = GridSearchCV(xgb, param_grid, cv=10, scoring='accuracy', return_train_score=False, verbose=1)
# ---> 13 clf_xgb.fit(X_train,y_train)
#      15 print(clf_xgb.best_params_)
#      16 y_pred_xgb = clf_xgb.predict(X_test)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1392, in GridSearchCV._run_search(self, evaluate_candidates)
#    1390 def _run_search(self, evaluate_candidates):
#    1391     """Search all candidates in param_grid"""
# -> 1392     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     830 if self.verbose > 0:
#     831     print(
#     832         "Fitting {0} folds for each of {1} candidates,"
#     833         " totalling {2} fits".format(
#     834             n_splits, n_candidates, n_candidates * n_splits
#     835         )
#     836     )
# --> 838 out = parallel(
#     839     delayed(_fit_and_score)(
#     840         clone(base_estimator),
#     841         X,
#     842         y,
#     843         train=train,
#     844         test=test,
#     845         parameters=parameters,
#     846         split_progress=(split_idx, n_splits),
#     847         candidate_progress=(cand_idx, n_candidates),
#     848         **fit_and_score_kwargs,
#     849     )
#     850     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     851         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852     )
#     853 )
#     855 if len(out) < 1:
#     856     raise ValueError(
#     857         "No fits were performed. "
#     858         "Was the CV iterator empty? "
#     859         "Were there no candidates?"
#     860     )
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1051, in Parallel.__call__(self, iterable)
#    1048 if self.dispatch_one_batch(iterator):
#    1049     self._iterating = self._original_iterator is not None
# -> 1051 while self.dispatch_one_batch(iterator):
#    1052     pass
#    1054 if pre_dispatch == "all" or n_jobs == 1:
#    1055     # The iterable was consumed all at once by the above for loop.
#    1056     # No need to wait for async callbacks to trigger to
#    1057     # consumption.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~\anaconda3\lib\site-packages\xgboost\core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\xgboost\sklearn.py:1250, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1230 model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
#    1231 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1232     missing=self.missing,
#    1233     X=X,
#    (...)
#    1247     label_transform=label_transform,
#    1248 )
# -> 1250 self._Booster = train(
#    1251     params,
#    1252     train_dmatrix,
#    1253     self.get_num_boosting_rounds(),
#    1254     evals=evals,
#    1255     early_stopping_rounds=early_stopping_rounds,
#    1256     evals_result=evals_result,
#    1257     obj=obj,
#    1258     feval=feval,
#    1259     verbose_eval=verbose,
#    1260     xgb_model=model,
#    1261     callbacks=callbacks,
#    1262 )
#    1264 if not callable(self.objective):
#    1265     self.objective = params["objective"]
#
# File ~\anaconda3\lib\site-packages\xgboost\training.py:188, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     115 def train(params, dtrain, num_boost_round=10, evals=(), obj=None, feval=None,
#     116           maximize=None, early_stopping_rounds=None, evals_result=None,
#     117           verbose_eval=True, xgb_model=None, callbacks=None):
#     118     # pylint: disable=too-many-statements,too-many-branches, attribute-defined-outside-init
#     119     """Train a booster with given parameters.
#     120
#     121     Parameters
#    (...)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#     191                           obj=obj, feval=feval,
#     192                           xgb_model=xgb_model, callbacks=callbacks,
#     193                           verbose_eval=verbose_eval,
#     194                           evals_result=evals_result,
#     195                           maximize=maximize,
#     196                           early_stopping_rounds=early_stopping_rounds)
#     197     return bst
#
# File ~\anaconda3\lib\site-packages\xgboost\training.py:81, in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79 if callbacks.before_iteration(bst, i, dtrain, evals):
#      80     break
# ---> 81 bst.update(dtrain, i, obj)
#      82 if callbacks.after_iteration(bst, i, dtrain, evals):
#      83     break
#
# File ~\anaconda3\lib\site-packages\xgboost\core.py:1680, in Booster.update(self, dtrain, iteration, fobj)
#    1677 self._validate_features(dtrain)
#    1679 if fobj is None:
# -> 1680     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                             ctypes.c_int(iteration),
#    1682                                             dtrain.handle))
#    1683 else:
#    1684     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %% [markdown]
# KNN Classifier

# %%
param_grid = {'n_neighbors':[8,12,15], 'weights':['uniform', 'distance'], 'metric' : ['manhattan', 'euclidean', 'cosine']}
knn = neighbors.KNeighborsClassifier()
# defining parameter range
grid = GridSearchCV(knn, param_grid, cv=10, scoring='accuracy', return_train_score=False, verbose=1)

# fitting the model for grid search

grid_search=grid.fit(X_train, y_train)
print(grid_search.best_params_)
y_pred_knn = grid_search.best_estimator_.predict(X_test)
print(classification_report(y_test, y_pred_knn))

_ = ConfusionMatrixDisplay.from_predictions(y_test, y_pred_knn)

# %% [markdown]
# MLP Classifier

# %%
mlp = MLPClassifier( 
    hidden_layer_sizes=(9,7,5,3)    
    )

param_grid = {'activation':['identity', 'logistic', 'tanh', 'relu'], 'learning_rate_init':(0.001, 0.005, 0.01)}

clf_mlp= GridSearchCV(mlp, param_grid, cv=10, scoring='accuracy', return_train_score=False, verbose=1)
clf_mlp.fit(X_train,y_train)
print(clf_mlp.best_params_)
y_pred_mlp = clf_mlp.best_estimator_.predict(X_test)
print(classification_report(y_test, y_pred_mlp))
_ = ConfusionMatrixDisplay.from_predictions(y_test, y_pred_mlp)
